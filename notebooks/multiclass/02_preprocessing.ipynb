# %% [markdown]
# # Personal view
#
# - **Target classes balancing:**
#
# Depending on the the percentage pie chart the target values should be balanced
# ![values_percentage.jpg](attachment:c0bf0c34-e545-42d2-b120-3a08df3079ca.jpg)
